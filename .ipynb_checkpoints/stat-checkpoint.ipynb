# %%
# !pip install --proxy 10.0.0.1:3128 numpy
# Out:
# Requirement already satisfied: numpy in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (1.24.2)

# %% [markdown]
#  --upgrade pip nltk gensim pandas pymorphy2 emoji numpy

# %% [markdown]
# # Статистика комментариев и использования в них эмодзи для сообществ социальной сети ВК по Алтайскому краю

# %% [markdown]
# ### Импорт необходимых библиотек

# %%
import pandas as pd
import nltk
from nltk.corpus import brown
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re
from gensim.models import Word2Vec as wv
from gensim.models import KeyedVectors
import pymorphy2
from pymorphy2 import MorphAnalyzer
import emoji
import zipfile
import numpy as np

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger_ru')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_ru.zip.
# True

# %%
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\universal_tagset.zip.
# True

# %% [markdown]
# ### Подготовка датасета

# %% [markdown]
# ##### Чтение датасета

# %%
colnames = ['index', 'comment']

# %%
comments = pd.read_csv('datasets/barneos22.csv', names=colnames, header=None)

# %%
comments
# Out:
#        index                                            comment
# 0        NaN                                                  0
# 1        0.0                                          Ледокол 🤣
# 2        1.0  Красавец! Какая же удивительная природа😊 столь...
# 3        2.0  [id457697599|Анастасия], да какие это люди? Ма...
# 4        3.0                                          Шикарный👍
# ...      ...                                                ...
# 1722  1721.0  [id255548341|Анастасия], люди по умнее, кому д...
# 1723  1722.0  [id258410293|Евгений], глупости говорите. У ме...
# 1724  1723.0  На видео министр здравоохранения Попов смешно ...
# 1725  1724.0  Огласите пожалуйста весь список, все 700 учреж...
# 1726  1725.0  Просматривая такие новости, у меня лично, возн...
#
# [1727 rows x 2 columns]

# %%
comments = comments.drop(labels = [0,1],axis = 0)

# %%
comments = comments.drop(columns = ['index'],axis = 1)

# %%
comments = comments.reset_index(drop=True)

# %%
comments
# Out:
#                                                 comment
# 0     Красавец! Какая же удивительная природа😊 столь...
# 1     [id457697599|Анастасия], да какие это люди? Ма...
# 2                                             Шикарный👍
# 3                                    "краснокнижного" )
# 4     [id56412943|Kaljn], косоглазого )\nСправа конв...
# ...                                                 ...
# 1720  [id255548341|Анастасия], люди по умнее, кому д...
# 1721  [id258410293|Евгений], глупости говорите. У ме...
# 1722  На видео министр здравоохранения Попов смешно ...
# 1723  Огласите пожалуйста весь список, все 700 учреж...
# 1724  Просматривая такие новости, у меня лично, возн...
#
# [1725 rows x 1 columns]

# %% [markdown]
# ##### Предобработка комментариев

# %% [markdown]
# Удаление из комментраиев-ответов имени и идентификатора пользователя [id255548341|Анастасия], которому адресован ответ

# %%
pattern = r'\[(.*?)\]'

def reply_delete(doc):
    doc = re.sub(pattern, ' ', str(doc))
    return doc

# %%
comments['comment'] = comments['comment'].apply(reply_delete)

# %%
comments
# Out:
#                                                 comment
# 0     Красавец! Какая же удивительная природа😊 столь...
# 1           , да какие это люди? Маленько не дотягивают
# 2                                             Шикарный👍
# 3                                    "краснокнижного" )
# 4       , косоглазого )\nСправа конвергирующий страбизм
# ...                                                 ...
# 1720   , люди по умнее, кому дорого свое здоровье, е...
# 1721   , глупости говорите. У меня не одному знакомо...
# 1722  На видео министр здравоохранения Попов смешно ...
# 1723  Огласите пожалуйста весь список, все 700 учреж...
# 1724  Просматривая такие новости, у меня лично, возн...
#
# [1725 rows x 1 columns]

# %%
patterns = "[A-Za-z0-9!#$%&'()*+,./:;<=>?@[\]^_`{|}~—\"\-]+"
stopwords_ru = stopwords.words("russian")
morph = MorphAnalyzer()

def lemmatize(doc):
    doc = re.sub(patterns, ' ', str(doc))
    for c in str(doc):
      if emoji.is_emoji(c):
          i = doc.index(c)
          doc = doc[:i] + doc[i:]
    tokens = []
    for token in doc.split():
        if token and token not in stopwords_ru and emoji.is_emoji(token) == False:
            token = token.strip()
            token = morph.normal_forms(token)[0]
            tokens.append(token)
        elif emoji.is_emoji(token):
            tokens.append(token)
    if len(tokens) > 2:
        return tokens
    return None

# %%
comments['comment'] = comments['comment'].apply(lemmatize)

# %%
comments = comments.dropna()

# %%
comments
# Out:
#                                                 comment
# 0     [красавец, какой, удивительный, природа😊, стол...
# 1           [какой, это, человек, маленько, дотягивать]
# 4        [косоглазый, справа, конвергировать, страбизм]
# 7                                  [каков, красавец, 😍]
# 8     [зачем, ❓, собраться, убивать, это, тот, стрел...
# ...                                                 ...
# 1720  [человек, умный, кто, дорого, свой, здоровье, ...
# 1721  [глупость, говорить, у, один, знакомый, родств...
# 1722  [на, видео, министр, здравоохранение, попов, с...
# 1723   [огласить, пожалуйста, весь, список, учреждение]
# 1724  [просматривать, такой, новость, лично, возника...
#
# [1328 rows x 1 columns]

# %% [markdown]
# ##### Проверка на наличие эмодзи в полученном датасете комментариев

# %%
def check(comment):
    flag=0
    for item in comment:
        if emoji.is_emoji(item):
      flag+=1
  if flag > 0:
    return(comment)
  return None

# %%
contain_emoji = comments.apply(check)
# Out:
# ['красавец', 'какой', 'удивительный', 'природа😊', 'столько', 'красота', 'вокруг', 'человек', 'готовый', 'всё', 'уничтожить', 'ради', 'забава']
# ['какой', 'это', 'человек', 'маленько', 'дотягивать']
# ['косоглазый', 'справа', 'конвергировать', 'страбизм']
# ['каков', 'красавец', '😍']
# ['зачем', '❓', 'собраться', 'убивать', 'это', 'тот', 'стрелять', 'птица', 'читать', 'это', 'пост']
# ['почему', 'такой', 'урод', 'садить']
# ['дбб', 'который', 'позвонить', 'если', 'слышать', 'уяснить', 'трогать', 'студент', 'школьник', 'другой', 'детский', 'учреждение', 'хороший', 'позвонить', 'ты', 'заняться', 'нечего']
# ['это', 'укр', 'вы', 'думать', 'послушать']
# ['всё', 'если', 'послушать', 'увидеть', 'почувствовать', 'глаз', 'выбить']
# ['везти', 'а', 'смена', 'мы', 'отменять', 'хотя', 'выгнать']
# ['тобыть', 'пара', 'быть', 'я', 'видеть', 'весь', 'полиция', 'уехать', 'политех']
# ['ну', 'красавчик', 'я', 'парковаться', 'нормальный', 'место', 'главное', 'никто', 'мешать']
# ['куча', 'этот', 'х', 'й', 'пока', 'растаять', 'лежать', '🤣']
# ['убрать', 'это', 'глыба', 'лёд', 'до', 'июнь', 'таять']
# ['двор', 'также', 'паркуются😂']
# ['бог', 'уборка', 'снег']
# ['кто', 'мешать', 'то', 'вылезти', 'заслуживать', 'уважение']
# ['ага', 'самый', 'сложный', 'вылезти', 'залезть', 'обратно', 'паджеро', 'сила']
# ['покоритель', 'вершина', 'больший', 'малый']
# ['нормальный', 'парковка', 'нормальный', 'машина', 'не', 'тротуар', 'газон', 'проход', 'пузотёрка', 'завидовать', 'спокойно']
# ['ну', 'всё', 'фен', 'шуя']
# ['масло', 'двигатель', 'вытекать', '😉']
# ['двигатель', 'сказать', 'спасибо', 'холодный', 'пуске🤣', 'масло', 'наверняка', 'отлить', 'заборника🤦\u200d♂️']
# ['прикинуть', 'просто', 'скатиться', 'завести']
# ['возможно', 'я', 'истина', 'претендовать']
# ['и', 'он', 'нарушить', 'там', 'газон', 'пешеходка', 'какой', 'претензия', 'найти', 'свободный', 'парковочный', 'место', 'говориться', 'завидовать', 'молча']
# ['данный', 'случай', 'завидовать', 'пешеход', 'водитель', 'пузотёрка', 'который', 'мочь', 'парковаться', 'также']
# ['думать', 'выбирать', 'какой', 'машинка', 'покупать']
# ['думать', 'деньга', 'хватать', 'покупка']
# ['ну', 'брать', 'салон', 'таевать', 'наш', 'салон', 'писать', 'тот', 'ещё', 'фрукт']
# ['и', 'хотеть', 'парковаться', '🙏']
# ['удобно', 'наверно', 'вылазить']
# ['минприрода', 'против', 'природа', 'прелесть', 'хорошо', 'суд', 'запретить']
# ['деньга', 'природа', 'пахнуть']
# ['также', 'отменить', 'строительство', 'башня', 'место', 'речной', 'вокзал', 'также', 'строительство', 'многоэтажка', 'место', 'цум', 'застройка', 'сквер', 'около', 'пл', 'сахаров', 'поднять', 'резонанс', 'если', 'молчать', 'всё']
# ['позный', 'барнаул', 'продать']
# ['поздно', 'можно', 'осуществить', 'возврат', 'ещё', 'возврат', 'процент', 'кто', 'возникнуть', 'желание', 'торговать', 'земля', 'если', 'остановить', 'такой', 'товарищ', 'скоро', 'земля', 'враг', 'начать', 'продавать']
# ['пффффф', 'хорошо', 'начать', 'пить', 'кофе']
# ['это', 'очень', 'кофе', 'вредный']
# ['вроде', 'центр', 'жить', 'никак', 'увидеть', 'змеева', 'антоненко', 'плакат', 'шея', 'здание', 'городской', 'управа', 'я', 'тот', 'застройка', 'порядок', 'тот', 'паблик', 'такой', 'могучий', 'неравнодушный', 'спас', 'как', 'толк']
# ['рано', 'мы', 'ещё', 'плакатик', 'стоять', 'вы', 'просто', 'разбираться', 'наш', 'план', 'видимо😁']
# ['база', 'запретить', 'строить']
# ['кто', 'везти', 'ехать', 'нет', 'весь', 'собраться', 'сходить', 'прокуратура', 'решить', 'навсегда', 'вопрос', 'очистка', 'и', 'установить', 'графика']
# ['думать', 'прокуратура', 'знать', 'обращение', 'это', 'панацея']
# ['знать', 'прокуратура', 'обращение', 'день', 'почистить']
# ['быть', 'каждый', 'год', 'сам', 'убирать', '🧹', 'круто', '👍🏻', 'дарить', 'платить', 'уборка', 'быть', 'а', 'крыша', 'побежать', 'сам', 'полезть']
# ['ха', 'ук', 'разобрать', 'денюжка', 'заложить', 'уборка', 'карман']
# ['пусть', 'управляйка', 'выставить', 'счёт', 'свой', 'услуга', '😆']
# ['как', 'склоняться', 'мысль', 'вариант', 'тсж', 'тсн', 'приемлемый', 'всё', 'таки', 'председатель', 'правление', 'жить', 'дом']
# ['председатель', 'поймать', 'подъезд', 'шанс', '🤣🤣🤣']
# ['собрать', 'человейник', 'такой', 'тсж', 'среди', 'квартира', 'просто', 'не', 'просто', 'многий', 'страна', 'мир', 'отказываться', 'многоэтажный', 'застройка', 'польза', 'малоэтажка', 'квартира']
# ['год', 'жить', 'дом', 'тсж', 'это', 'просто', 'ужас', 'никто', 'делать', 'а', 'дворник', 'весь', 'мусор', 'помойка', 'снести', 'подвал', 'ковёр', 'кастрюля', 'мешок', 'сапог', 'когда', 'увидеть', 'закрытый', 'ячейка', 'забитый', 'просто', 'жесть', 'выносить', 'сам', 'прийтись', 'но', 'год', 'натаскать', 'вынести', 'мусорк', 'переслать', 'ук', 'там', 'другой', 'руководство', 'измениться', 'хороший', 'сторона']
# ['жить', 'год', 'дом', 'квартира', 'бывать', 'косяк', 'целое', 'нормально', 'двор', 'чиститься', 'подъезд', 'убираться', 'ремонт', 'делаться', 'менять', 'дверь', 'окно', 'подъезд', 'ремонтировать', 'крыша', 'покупать', 'прибор', 'регулировать', 'подача', 'отопление', 'зависимость', 'погода', 'сильно', 'упасть', 'платёж', 'отопление']
# ['это', 'повезти', 'человек', 'зависеть']
# ['тсж', 'огромный', 'минус', 'это', 'стоимость', 'итог', 'обслуживание', 'если', 'ставить', 'реальный', 'ценник', 'который', 'действительно', 'делать', 'должник', 'и', 'работать', 'в', 'ук', 'специалист', 'обслуживать', 'несколько', 'дом', 'вывозить', 'дворник', 'фига', 'найти', 'сегодня', 'копейка', 'никто', 'месть', 'мыть', 'сантехник', 'обслуживать', 'свой', 'теплопункт', 'это', 'отдельный', 'статья', 'расход', 'и', 'председатель', 'тыс', 'стать', 'нормальный', 'выслушивать', '💩', 'людской']
# ['согласный', 'идеальный', 'вариант', 'сожаление']
# ['тсж', 'председатель', 'жить', 'соседний', 'езда', 'только', 'нах', 'нужно', 'обидно', 'хотеть', 'поменять', 'никто', 'соглашаться', 'её', 'заменить']
# ['тсж', 'двор', 'чистить', 'мусор', 'управляйка', 'вывозить', 'свой', 'автомобиль', 'бороться', 'смысл', 'писать', 'администрация', 'индустриальный', 'район', 'нарушение', 'видеть', 'так', 'жить', '…', 'это', 'спорный']
# ['а', 'ук', 'такой', 'чистить', 'смотреть', 'почистить']
# ['пусть', 'счёт', 'адрес', 'ук', 'выставлять', 'провести', 'работа', 'если', 'ошибаться', 'закон', 'пункт', 'так', 'всё', 'закон']
# ['умножить', 'кол', 'человек', 'думать', 'сумма', 'нормальный']
# ['правильно', 'считать', 'делить', 'нужно']
# ['дворник', 'получать', 'так', 'зарплата', 'часовой', 'день', 'рабочий', 'день', 'получаться', 'примерно', 'р', 'час', 'разделить']
# ['вы', 'правильно', 'считать', 'да', 'любой', 'случай', 'важный', 'сумма', 'важный', 'прецедент', 'так', 'уборка', 'весь', 'услуга', 'который', 'оказывать', 'ук', 'и', 'ремонт', 'подъезд', 'герметизация', 'шов', 'так', 'далее']
# ['ну', 'первый', 'это', 'здорово', 'что', 'сам', 'почистить', 'красота', 'чистота', 'сам', 'ходить', 'приятно', 'наверное', 'дворник', 'в', 'новость', 'говориться', 'хватать', 'дворник', 'зарплата', 'так']
# ['ук', 'вообще', 'ленивый', 'организация', 'сколько', 'разговор', 'заводила', 'друг', 'многий', 'упровляйка', 'либо', 'хреновый', 'либо', 'вообще', 'забить', 'всё']
# ['поэтому', 'нужный', 'тсж', 'вот', 'собрать', 'дом', 'квартира', 'мы', 'дом', 'попытаться', 'собрать', 'тсж', 'смочь']
# ['когда', 'начать', 'управляйка', 'наказывать', 'неисполнение', 'свой', 'обязанность']
# ['пока', 'заносить', '«куда', 'надо»']
# ['только', 'быть', 'наказывать', 'штраф', 'деньга', 'дом', 'пойти', 'из', 'свой', 'карман', 'выплатить']
# ['молодец', 'убрать', 'сейчас', 'ук', 'начать', 'делать']
# ['зп', 'удерживать', 'решение', 'суд', 'шевелиться', 'начать']
# ['совершенно', 'правый', 'штраф', 'итог', 'жилец', 'сам', 'оплатить']
# ['у', 'вообще', 'дворник', 'забыть', 'выглядеть', 'лом', 'лопата', 'круглый', 'год', 'ведро', 'метёлка', 'всё', 'ржать', 'материться', 'жэу', 'индустриальный', 'район', 'жалоба', '«забило»', 'к', 'мы', 'балтийский', 'проехать', 'пешком', 'проблема', 'молодец', 'жилец', 'наш', 'организовать']
# ['пора', 'ук', 'частный', 'рука', 'убирать']
# ['вообще', 'частник', 'зло', 'ни', 'медицина', 'строительство', 'перевозка', 'человек', 'автобус', 'дядя', 'заинтересованный', 'прибыль', 'должный', 'заниматься', 'это', 'социалка', 'заниматься', 'это', 'должный', 'государство']
# ['война', 'дело', 'такое…']
# ['дело', 'война', 'губернатор', 'сказать', 'никто', 'никто', 'держать', 'регион']
# ['отток', 'специалист', 'мобилизация', 'влиять', 'дефицит', 'кадр', 'целое', 'дефицит', 'квалифицировать', 'кадр', 'далёкий', 'усиливаться', 'сейчас', 'позабрать', 'война', 'один', 'пенсионер', 'остаться']
# ['хватить', 'сво', 'приписывать', 'сколько', 'мобилизовать', 'аж', 'нехватка', 'просто', 'такой', 'зп', 'никто', 'идти', 'пенсионер', 'это', 'подработка', 'молодой', 'это', 'семья', 'ипотека', 'жена', 'ребёнок']
# ['платить', 'другой', 'место', 'пойти', 'там', 'условие', 'хороший']
# ['замалчивать', 'уже', 'молчать', 'сколько', 'год', 'посмотреть', 'что', 'привести']
# ['правильно', 'надо', 'ещё', 'год', 'назад', 'сво', 'устроить', 'молчать', 'молчать']
# ['ещё', 'кухонный', 'писака', 'революционер']
# ['появиться', 'зп', 'специалист', '🤣🤣🤣']
# ['война', 'начаться', 'долго', 'думать', 'вступить']
# ['интересно', 'рынок', 'труд', 'пропасть', 'молодой', 'мужчина', 'видимо', 'случиться']
# ['опыт', 'опыт', 'нанимать']
# ['всё', 'ваш', 'предположение', 'ошибочно']
# ['просто', 'молодой', 'конкретно', 'забить', 'подобный', 'работа']
# ['зарплата', 'в', 'размер', 'весь', 'корень', 'проблема']
# ['просто', 'так', 'молодой', 'пойти', 'такой', 'работа']
# ['рыночка', 'порешать', 'капитализм', 'знать', 'стартовый', 'должность', 'копейка', 'конкурс', 'человек', 'производство', 'в', 'итог', 'кандидатский', 'человек', 'специальность', 'идти', 'работать', 'а', 'касаться', 'рабочий', 'специальность', 'деньга', 'всё', 'решать', 'и', 'работодатель', 'вместо', 'повышение', 'зарплата', 'который', 'мочь', 'привлечь', 'молодёжь', 'нанимать', 'наиболее', 'социально', 'незащищённый', 'специалист', 'пенсионер', 'опыт', 'который', 'платить', 'низкий', 'з', 'п', 'учитывать', 'демографический', 'яма', 'потенциальный', 'рабочий', 'пенсионер', 'раз', 'молодой', 'человек', 'далёкий', 'плохой']
# ['какой', 'сельский', 'хозяйство', 'работать', 'тр', 'никто', 'удивить', 'кадр', 'охота', 'настоящий', 'транспортный', 'компания', 'техника', 'работать', 'далеко']
# ['сам', 'дело', 'маленький', 'на', 'завод', 'разный', 'зайти', 'посмотреть']
# ['а', 'хороший', 'зарплата', 'готовый', 'наниматься']
# ['зависеть', 'твой', 'умение', 'зарабатывать']
# ['работа', 'работать', 'некого']
# ['оксить', 'работа', 'готовый', 'работать', 'ипотека']
# ['и', 'коммуналка', 'ещё']
# ['маленький', 'мужик', 'мало', 'платить']
# ['вот', 'правильно', 'центр', 'москва', 'наш', 'точка', 'проход', 'давать']
# ['видеть', 'интерес', 'свой', 'персона', 'ибо', 'нехватка', 'рабочий', 'рука', 'это', 'миф', 'буржуй', 'нужный', 'безмолвный', 'покорный', 'раб', 'пенсионер', 'подходить', 'роль', 'идеально']
# ['смотреть', 'специальность', 'домой', 'вы', 'никто', 'прийти', 'судебный', 'пристать']
# ['мой', 'хождение', 'собеседование', 'превратиться', 'игра', 'джеймс', 'бонд', 'посетить', 'масса', 'контора', 'везде', 'один', 'сейчас', 'работать', 'выгодный', 'работать']
# ['работать', 'копейка', 'желательно']
# ['год', 'ходить', 'контора', 'высокий', 'требование', 'ленивый', 'просто', 'тупой', '😄']
# ['нежелание', 'взглянуть', 'правда', 'глаз', 'прикрывать', 'эфемерный', 'понятие', 'ленность', 'тупость', 'далёкий', 'такой', 'обвинить', 'русский', 'генетический', 'предрасположенность', 'вышеобозначить', 'порок']
# ['правда', 'если', 'тупой', 'такой', 'время', 'смочь', 'найти', 'достойный', 'работа', 'лишь', 'виноватый', 'сваливать', 'другой']
# ['саша', 'проснуться', 'ой', 'страшно', 'расставаться', 'иллюзия', 'реальность', 'явиться', 'каждый', 'дом']
# ['знать', 'также', 'друг', 'ездить', 'черёмного', 'барнаул', 'наслать', 'работа', 'получать', 'такой', 'ныть', 'причина', 'ты']
# ['это', 'платить', 'секрет']
# ['😀', 'видный', 'разница', 'интеллект']
# ['фактор', 'низкий', 'зп', 'сво']
# ['полгода', 'мобилизация', 'ваш', 'это', 'причина', 'резко', 'забрать', 'тысяча', 'специалист', 'квалифицировать', 'барнаул', 'такой', 'смех', 'писать']
# ['кто', 'забрать', 'место', 'обучать', 'новый', 'это', 'время', 'смотреть', 'специальность', 'кто', 'говорить', 'зп', 'смешной', 'человек', 'стать', 'вахта', 'гонять', 'подработка', 'платить', 'предприятие', 'каторга', 'грош', 'работать', 'ради', 'купить', 'покушать', 'далёкий', 'работать', 'человек', 'умнеть', 'начать', 'надеяться', 'просто', 'идти', 'горбатиться']
# ['забрать', 'это', 'сколько', 'масштаб', 'город', 'на', 'вахта', 'гонять', 'год', 'а', 'зп', 'это', 'первый', 'главное', 'проблема']
# ['надеяться', 'просто', 'человек', 'поумнеть', 'перестать', 'идти', 'копейка', 'надеяться', 'это', 'спровоцировать', 'рост', 'зп', 'быть', 'действительно', 'пенсионер', 'трогать']
# ['это', 'факт', 'потому', 'нехватка', 'начаться', 'глобальный']
# ['депутат', 'нанимать', '⚠']
# ['депутат', 'идти', 'стать', 'второй', 'жириновский']
# ['так', 'последний', 'пять', 'год', 'не', 'морочта', 'голова']
# ['человек', 'становиться', 'умный', 'а', 'пердолить', 'готовый', 'любой', 'копейка', 'работать', 'закончиться']
# ['закончиться', 'в', 'близкий', 'год', 'демографический', 'ям', 'ситуация', 'плохой', 'молодой', 'специалист', 'маленький', 'пенсионер', 'лицо', 'предпенсионный', 'возраст']
# ['а', 'что', 'дорого', 'сделать', 'дешёвый', 'опять', 'бюджет', 'пилить', 'ваш', 'звёздный', 'час', 'торг', 'открытый', 'вперёд']
# ['а', 'предыдущий', 'сдуться']
# ['хороший', 'потратить', 'деньга', 'охрана', 'чтоб', 'пресекаться', 'доступ', 'парк', 'гопник', 'собачник', 'наркоман', 'голубятник', 'прочий', 'люмпен']
# ['парка', 'зона', 'выгул', 'собака', 'оборудовать', 'как', 'владелец', 'собака', 'наркоман', 'один', 'список', 'обозначить', 'добрый', 'человек']
# ['соблюдать', 'правило', 'формально', 'смотреть', 'окружающий', 'протаранить', 'всегда', 'делать']
# ['с', 'двор', 'знак', 'поставить', 'направо', 'проблема', 'решить']
# ['знак', 'кто', 'останавливать']
# ['думать', 'право', 'получить', 'такой', 'познание', '🤦\u200d♂️', 'отличие', 'перекрёсток', 'зона', 'разворот', 'проезжий', 'часть', 'учить', 'самый', 'первый', 'занятие', 'автошкола', 'правило', 'открыть', 'разъяснение', 'всё', 'это']
# ['правелами', 'прописать', 'траектория', 'проезжать', 'место', 'разворот', 'любой', 'помеха', 'встречный', 'движение']
# ['у', 'тот', 'выезжать', 'двор', 'вообще', 'номер', 'шешнадцатый', 'самый', 'последний', 'приоритет', 'пешеход', 'кошка', 'собака', 'идти', 'тротуар', 'так', 'смор']
# ['полюбома', 'знак', 'движерие', 'право', 'должный']
# ['а', 'знак', 'вообще', 'лишний']
# ['выехать', 'двор', 'уступить', 'весь', 'остановиться', 'середина', 'технологический', 'разрыв', 'выезжать', 'ты', 'лоб', 'справа', 'желать', 'развернуться', 'как', 'ситуация']
# ['приезжать', 'правило', 'проезд', 'место', 'разворот', 'выезжать', 'двор', 'должный', 'уступать', 'баранов', 'посылать', 'стойло', 'ну', 'правило', 'три', 'далее', 'забывать']
# ['схема', 'верный', 'разворот', 'ряд', 'перестройка', 'а', 'схема', 'почему', 'ряд', 'сразу']
# ['схема', 'смотреть', 'в', 'пдд', 'всё', 'прописать', 'остаться', 'исполнять', '🤷']
# ['а', 'расчистить', 'место', 'разворот', 'два', 'полоса', '🤔']
# ['на', 'перекрёсток', 'большой', 'радиус', 'технологический', 'разрыв', 'малый', 'сложный']
# ['бред', 'пдд', 'писать']
# ['это', 'правило', 'это', 'обычай', 'который', 'следовать', 'соблюдать', 'всякий', 'случай', 'автошкола', 'учить', 'разъезжаться']
# ['понятие', 'иметь', 'учить', 'разъезжаться', 'автошкола', 'пдд', 'написать']
# ['факт', 'лёгкий', 'правило', 'проезжать', 'особо', 'видеть', 'наоборот', 'делать']
# ['пдд', 'сожаление', 'траектория', 'сказать', 'разъяснение', 'который', 'говориться', 'водитель', 'траектория', 'выбирать', 'самостоятельно', 'олень', 'автошкола', 'рекомендовать', 'разъезжаться', 'правый', 'борт', 'перекрёсток', 'разумеется']
# ['что', 'перекрёсток', 'правый', 'борт']
# ['получаться', 'встречный', 'полоса', 'движение', 'въезжать', 'напоминать', 'говорить', 'разворот', 'знак']
# ['перекрёсток', 'один', 'пересечение', 'проезжий', 'часть', 'встречка', 'выполнять', 'разворот']
# ['это', 'такой', 'информация', 'впервые', 'слышать']
# ['й', 'западный', 'пдд']
# ['разворот', 'это', 'поворот', 'левый', 'крайний', 'левый', 'положение', 'место', 'разворот', 'поехать', 'дальний', 'радиус', 'попадать', 'полоса', 'встречный', 'движение', 'на', 'перекрёсток', 'начать', 'разворот', 'малый', 'радиус', 'попадать', '«встречку»', 'всё', 'просто']
# ['разворот', 'один', 'направление']
# ['разворот', 'два', 'направление', 'встречный', 'полоса', 'проезжий', 'часть', 'на', 'картинка', 'изобразить', 'участок', 'который', 'встречный', 'полоса', 'и', 'еслиб', 'это', 'перекрёсток', 'полоса']
# ['встречный', 'разворот', 'никто', 'делать', 'избежание', 'сам']
# ['это', 'неправильно', 'если', 'возможность', 'развести', 'поток', 'развести']
# ['курс', 'знак', 'запрещать', 'левый', 'поворот', 'по', 'ваш', 'это', 'знак', 'невозможно', 'развернуться', '🤣']
# ['смысл', 'правильно', 'запрещать', 'пол', 'страна', 'такой', 'разворот', 'че', 'далеко', 'ходить', 'город', 'полно', 'такой', 'разворот', 'один', 'попов', 'трактовый', 'каждый', 'разворот']
# ['развернуться', 'малый', 'радиус', 'едь', 'выезжать', 'двор', 'отдыхать', 'главный']
# ['выезжать', 'двор', 'пересечь', 'пол', 'дорога', 'какой', 'радиус', 'делать', 'разворот']
# ['дать', 'ситуация', 'возможный', 'разворот', 'большой', 'малый', 'радиус', 'это', 'перекрёсток']
# ['перекрёсток', 'почему', 'малый', 'радиус']
# ['многие', 'рассказать', 'разворот', 'это', 'левый', 'поворот', 'оказаться', 'встречка', 'особо', 'продвинуть', 'приплести']
# ['ответ', 'показать', 'картинка', 'стенд', 'западный', 'кабинет', 'разбор']
# ['сказать', 'один', 'пересечение', 'проезжий', 'часть', 'исаков', 'ну', 'перекрёсток']
# ['быть', 'правый', 'тот', 'дорога', 'иметь', 'два', 'проезжий', 'часть', 'который', 'разделительный', 'полоса']
# ['наступить', 'время', 'литровка', 'магазин', 'таскать', '😁']
# ['паводок', '…', 'водоканал', 'справляться']
# ['заверение', 'директор', 'водоканал', 'дорого', 'стоить', 'хотеться', 'хотя', 'роспотребнадзор', 'выслушать']
# ['выпить', 'литрушечка', 'свой', 'безопасный', 'водичка']
# ['фильтр', 'наш', 'всё']
# ['год', 'заказывать', 'вода', 'тина', 'воняет🤣']
# ['смотреть', 'аквафора', 'спасать', 'без', 'вода', 'вонять', 'зуб', 'чистить', 'хотеться']
# ['кипячение', 'спасать', 'фильтр', 'запах', 'оставаться']
# ['это', 'наверно', 'наполнитель', 'фильтр', 'зависеть', 'у', 'вонять', 'отфильтровать']
# ['сам', 'кран', 'фильтр', 'стоить', 'недавно', 'меняный', 'обычный', 'напольный', 'фото', 'пост', 'всё', 'равно', 'пахнуть', 'мочь', 'чуствовать', 'просто', 'чувствительность', 'запах', 'сильно', 'идти']
# ['давно', 'пить', 'вода', 'ток', 'магазин', '😒дажа', 'фильтр', 'помогать']
# ['магазин', 'тот', 'самый', 'вода', 'кран', 'раз', 'дорогой', 'проходить', 'карачинский']
# ['куяс', 'копнуть', 'аж']
# ['поверь', 'измениться', 'тот', 'пора']
# ['соответствовать', 'норма', 'санпин', 'ага', 'кошка', 'дристать', 'вода', 'кран', 'фильтр', 'справляться', 'пить']
# ['не', 'помнить', 'такой', 'прошлый', 'год', 'позапрошлый']
# ['хороший', 'но', 'прям', 'душа', 'вонища']
# ['каждый', 'весна', 'такой']
# ['дело', 'обь', 'начинать', 'попадать', 'талый', 'вода', 'становиться', 'мутный', 'появляться', 'характерный', 'привкус', 'а', 'напрямую', 'река', 'пить', 'тогда', 'нафиг', 'плач', 'водоканал']
# ['водичка', 'река', 'попадать', 'ты', 'квартира', 'не', 'мочь', 'платить', 'каждый', 'утро', 'речной', 'ведро', 'ездить']
# ['запах', 'тина', 'напрямую', 'река', 'очистка']
# ['тоже', 'помнить', 'предыдущий', 'год']
# ['зональный', 'район', 'вода', 'тухлый', 'болотный', 'цвет', 'реально', 'грязный', 'вода', 'она', 'цветок', 'поливать', 'пить', 'кожа', 'мытьё', 'вода', 'красный', 'пятно', 'так', 'специалист', 'утверждать', 'вода', 'соответствовать', 'норма', '🤦\u200d♂️']
# ['здравствуйте', 'подсказать', 'пожалуйста', 'населить', 'пункт', 'район', 'вы', 'говорить', 'точный', 'адрес', 'уточнить', 'информация']
# ['соколово', 'всё', 'жаловаться', 'село']
# ['с', 'добрый', 'утром', 'лёгкий', 'день']
# ['добрый', 'утро', 'алтай', 'хороший', 'день', 'весь', '✌']
# ['минус', 'вообще', 'утро', '☝🤗']
# ['добрый', 'утро', 'на', 'ставить', 'эксперимент', 'жизнь', 'сладкоежка', 'неделя', 'есть', 'сахаросодержащий', 'продукт', 'черещ', 'день', 'есть', 'свёкла', 'тёрка', 'сладкий', 'вкусный', 'то', 'убирать', 'сахар', 'рацион', 'первый', 'появляться', 'бодрость', 'далее', 'вкусовой', 'рецептор', 'обновляться', 'сказать', 'поверьте', 'диета', 'обычный', 'еда', 'заиграть', 'новый', 'вкусовой', 'краска']
# ['привет', 'вегана', 'говорить', 'польза', 'овощ', 'равно', 'смотреть', 'мясо', 'аппетит', '😅👌🏻']
# ['жить', 'сибирь', 'холодно', 'мясо', 'кушать', 'вегетарианец', 'бали🤔']
# ['солёный', 'огурец', 'зелёный', 'чаемый', 'казаться', 'верхом', 'кулинария']
# ['🤣самый', 'надёжный', 'вариант', 'безотказный', 'ак']
# ['отказывать', 'твой', 'ак']
# ['добрый', 'утро', 'прекрасный', 'день', 'весь', '🤗']
# ['спасибо', 'совет', 'надо', 'заработать', 'процент', 'ммм', 'да', 'взятка']
# ['бодрый', 'утро', '☀']
# ['хотеть', 'купить', 'квартира', 'мотивация', 'жизнь😐']
# ['добрый', 'ночь', '😉']
# ['плохо', 'номер', 'таз', 'попасть', 'кадр', 'в', 'какой', 'район', 'это']
# ['м', 'нк', 'внимательно', 'смотреть']
# ['м', 'нк', 'хёндэ', 'солярис', 'если', 'зрение', 'подводить']
# ['м', 'регион', 'вроде']
# ['спасибо', 'обратить', 'внимание']
# ['интернет', 'знать', 'помнить']
# ['ты', 'это', 'дать', 'поехать', 'искать', 'добиваться', 'правосудие']
# ['через', 'оптик', 'снять', 'такой']
# ['хотеть', 'жить', 'уметь', 'вертеться', 'лох', 'мамонт', 'вымереть', 'и', 'поговорка', 'пословица', 'данный', 'тематика']
# ['твой', 'бабка', 'объебут', 'быть', 'говорить']
# ['бабка', 'конченый', 'пох']
# ['жалко', 'человек', 'который', 'свой', 'наивность', 'простота', 'попадаться', 'такой', 'схема', 'естественный', 'отбор', 'иначе']
# ['мышление', 'детский', 'сорянин', 'ну', 'это', 'сказать', 'молодой', 'старичок', 'нихрен', 'шарить', 'учиться', 'поздно']
# ['извинить', 'взрослый', 'понять']
# ['твой', 'ровесник', 'интересный', 'мышление', 'просто', 'непонятный', 'а', 'ребёнок', 'педофил', 'секс', 'развести', 'сказать', 'лох']
# ['судить', 'весь', 'бабка', 'пойти']
# ['сравнение', 'подходить', 'ребёнок', 'маленький', 'глупый', 'многое', 'понимать', 'старик', 'жизнь', 'прожить', 'должный', 'понимать', 'покупать', 'цена', 'я', 'старик', 'жаль', 'нисколько', 'место', 'уступать', 'общественный', 'место', 'мочь', 'считать', 'плохой', 'человек', 'это', 'мой', 'личный', 'мнение', 'решение', 'просто', 'запомнить', 'один', 'никто', 'ты', 'позаботиться', 'кроме', 'сам', 'ни', 'старик', 'ровесник', 'друг', 'ребёнок', 'смысл', 'жалеть', 'никто', 'играть', 'публика', 'глаз', 'общественность', 'поставиться', 'правильный', 'это', 'фальша', 'жизнь', 'устроить', 'другой', 'если', 'прохавал', 'ты', 'предстоять', 'это', 'узнать', 'друг']
# ['наверно', 'курс', 'старик', 'терять', 'свой', 'ум', 'год', 'откроить', 'секрет', 'это', 'частый', 'явление', 'а', 'такой', 'жизненный', 'кредо', 'лес', 'одиночество', 'жить', 'бедный', 'твой', 'окружение']
# ['не', 'хотеть', 'брать']
# ['сказать', 'это', 'твой', 'мать', 'впялить', 'подобный', 'сильно', 'сомневаться', 'надеяться', 'герой', 'ролик', 'х', 'й', 'лоб', 'выростит', 'тачка', 'сгореть', 'чудесный', 'товар', 'парковка', '😈']
# ['мама', 'значит', 'нужный', 'контроль', 'и', 'этот', 'ответственность', 'ты']
# ['сволочь', 'оставить', 'бабушка', 'одеяло']
# ['цыган', 'что', 'взять…']
# ['ситуация', 'довольно', 'сложный', 'сам', 'сталкиваться', 'свой', 'тесть', 'тёща', 'втюхали', 'подобный', 'фуфло', 'а', 'придраться', 'невозможно', 'всё', 'законно', 'товар', 'исполнять', 'свой', 'функционал', 'исправный', 'даром', 'гумно', 'дешманский', 'а', 'лохотрон', 'товар', 'почта', 'так', 'сегмент', 'рынок', 'продолжать', 'существовать', 'пока', 'такой', 'покупатель']
# ['бабушка', 'фильтр', 'купить', 'тыс', 'хотя', 'реальнач', 'цена', 'она', 'очухаться', 'заявление', 'писать', 'полиция', 'отказать', 'возбуждение', 'дело']
# ['описать', 'выше', 'принцип', 'работать', 'подобный', 'контора', 'максимум', 'мочь', 'сделать', 'это', 'наказать', 'способ', 'нужно', 'действовать', 'осмотрительно', 'попасть', 'статья', 'ук', 'рф', '🤷']
# ['думать', 'снова', 'парковка']
# ['долб', 'еб', 'водятел']
# ['пешик', 'вообще', 'недалеко', 'уйти']
# ['некоторый', 'пешеход', 'думать', 'поезд', 'пропустить', 'остановиться', 'машина']
# ['что', 'такой', 'важный', 'искать', 'смартфон', 'находиться', 'пп', 'гуглить', 'грант', 'абс', '🤷\u200d♂️']
# ['ровно', 'искать', 'телефон', 'водитель', 'сидя', 'руль', 'обгонять', 'пп', 'знак', 'я', 'сегодня', 'двое', 'такой', 'видеть', 'давно', 'пора', 'штраф', 'выписывать', 'франция', 'фотография', 'человек', 'телефон', 'руль', 'и', 'важно', 'ехать']
# ['наличие', 'зависеть', 'комплектация', 'скорее']
# ['использование', 'телефон', 'руль', 'итак', 'штраф', 'верный', 'заготовка', 'вообще', 'это', 'обсуждать', 'сторона', 'водитель', 'коап', 'пдд', 'а', 'пешеход', 'инстинкт', 'самосохранение', 'получаться', 'водитель', 'платить', 'нарушение', 'рубль', 'свобода', 'пешик', 'здоровье', 'жизнь', 'что', 'кто', 'дорогой', 'выбор', 'они', 'лично', 'выбирать', 'жизнь', 'один', 'никак']
# ['видно', 'замедлить', 'торможение', 'юзом', 'идти', 'колесо', 'заблокировать']
# ['калин', 'пусть', 'знать', 'искать', 'ответ', '📲📲']
# ['золотой', 'слово', 'золото', 'памятник', 'тот', 'пешеход', 'возомнить', 'бессмертный', 'выше', 'закон', 'физика', 'жестоко', 'водитель', 'сесть', 'выйти', 'пешеход', 'лечь', 'встать', 'неудачный', 'стечение', 'обстоятельство', 'мочь', 'хэйтить', 'сколько', 'угодный', 'факт', 'остаться', 'факт', '🤷']
# ['похрить', 'штраф', 'жизнь', 'один', 'думать', 'голова', 'смотреть', 'сторона', 'некоторый', 'пешиход', 'думать', 'зебра', 'бессмертный']
# ['пешеход', 'поднять', 'штраф', 'минимум', 'так', 'р', 'а', 'сам', 'свой', 'жизнь', 'беспокоиться', 'по', 'правило', 'пешеход', 'должный', 'начинать', 'движение', 'пока', 'убедиться', 'водитель', 'уступать']
# ['начать', 'движение', 'это', 'безопасно', 'и', 'формально', 'закон', 'закон', 'физика', 'кстати', 'штраф', 'это', 'предусмотреть', 'вообще']
# ['они', 'встретиться', 'нужный', 'место']
# ['ну', 'ясно', 'водитель', 'виноватый', 'пешеходный', 'переход', 'тд', 'господин', 'пешеход', 'детство', 'втолковывать', 'посмотреть', 'налево', 'дойти', 'середина', 'посмотреть', 'направо', 'убедиться', 'пропускать', 'идти', 'звезда', 'телефон', 'втыкать', 'обочина', 'сохраниться', 'пофига', 'машина', 'юзом', 'тащить', 'лёд', 'заблокировать', 'колесо']
# ['найти', 'место', 'телефон', 'смотреть']
# ['водитель', 'обязать', 'снизить', 'скорость', 'пп', 'и', 'учитывать', 'дорожный', 'покрытие', 'а', 'телефон', 'зависать', 'судить', 'видео']
# ['спороть', 'водитель', 'оправдывать', 'пешеход', 'пдд', 'обязанность', 'убедиться', 'безопасность', 'переход', 'водитель', 'больной', 'нетрезвый', 'неадекватный', 'авто', 'неисправный', 'отказать', 'тормоз', 'тд', 'причина', 'жизнь', 'сотня', 'жизнь', 'пешеход', 'один', 'поднять', 'глаз', 'телефон', 'помочь', 'жизнь', 'сохранить', 'остаться', 'инвалид']
# ['сегодня', 'гололёд', 'лютый', 'тормозить', 'пешком', 'начинать', 'метр', 'очко', 'помогать', 'шип', 'вгрызаться', 'лёд']
# ['козёл', 'урод', 'это', 'бесспорный', 'но', 'учитывать', 'существование', 'такой', 'другой', 'козлов', 'урод', 'правило', 'дорожный', 'движение', 'обязывать', 'пешеход', 'переход', 'убедиться', 'пропускать', 'этот', 'козёл', 'плохой', 'случай', 'сесть', 'время', 'пешеход', 'лечь', 'навсегда']
# ['выше', 'написать', 'такой', 'бессмертный', 'согласный', 'полностью', 'порой', 'возникать', 'ощущение', 'жизнь', 'дорога', 'слово']
# ['идти', 'царица', 'свалиться', 'мешок🤣']
# ['завтра', 'больной', 'нетрезвый', 'неадекватный', 'так', 'далее', 'въехать', 'другой', 'водитель', 'лоб', 'погибнуть', 'что', 'это', 'сказать']
# ['связь', 'ваш', 'вопрос', 'пост']
# ['больной', 'нетрезвый', 'неадекватный', 'въехать', 'лоб', 'другой', 'водитель', 'делать', 'разделитель', 'встречный', 'поток', 'напрочь', 'отсутствовать']
# ['у', 'водитель', 'грант', 'ум']
# ['виноватый', 'оба', 'пешеход', 'телефон', 'водить', 'смотреть', 'дорога']
# ['виноватый', 'водитель', 'но', 'больница', 'странно', 'пешеход', 'надеяться', 'человек', 'посмотреть', 'видео', 'стать', 'относиться', 'переход', 'проезжий', 'часть', 'также', 'ответственно', 'парень', 'который', 'идти', 'следом', 'девушка', 'смотреть', 'сторона']
# ['думать', 'пешеходный', 'переход', 'безопасно', 'забывать', 'погодный', 'условие', 'позволять', 'остановить', 'автомобиль', 'моментально', 'водить', 'виноватый', 'пешик', 'мочь', 'сторона', 'смотреть', 'мобила', 'целый']
# ['мочь', 'остановить', 'машина', 'заранее', 'видеть', 'пешеход', 'стоить', 'право', 'сдать', 'машина', 'продать', 'ибо', 'водить', 'ты', 'такой', 'случай', 'опасно', 'окружающий']
# ['водить', 'смотреть', 'дорога', 'учесть', 'вчера', 'сегодня', 'разный', 'состояние', 'дорога', 'вчерашний', 'метр', 'торможение', 'сегодня', 'превращаться', 'особенно', 'место', 'перекрёсток', 'пешеходник', 'часто', 'тормозить', 'машина', 'накатываться', 'лёд']
# ['летать', 'всё', 'ещё', 'грант', 'машина', 'очень', 'лёгкий', 'либо', 'разгоняться', 'гололёд', 'либо', 'заранее', 'продумывать', 'торможение', 'переход']
# ['качественный', 'неевропейский', 'шип', 'ширина', 'правильный', 'давление', 'нормально', 'цепляться', 'лёд']
# ['уж', 'простить', 'пешеход', 'явно', 'бессмертный', 'поход', 'редкий', 'безалаберность']
# ['именно', 'переход', 'сбивать', 'тип', 'манёвр', 'завершать', 'машина', 'занести', 'считать', 'правильный']
# ['данный', 'случай', 'телефон', 'залипнуть']
# ['причём', 'частый', 'статистика']
# ['он', 'она', 'специально', 'наехать', 'пешеходный', 'переход', 'идти', 'пешеход', 'что', 'необходимо', 'остановиться']
# ['причём', 'завершать', 'переход🤦\u200d♂️']
# ['присмотреться', 'авто', 'юзом', 'заблоченный', 'колесо', 'нести', 'лёд', 'специально', 'не', 'думать']
# ['юля', 'оправдывать', 'водитель', 'виноватый', 'полностью', 'должный', 'учитывать', 'свой', 'автомобиль', 'дорожный', 'покрытие']
# ['водитель', 'притормаживать', 'гололёд', 'знак', 'висеть', 'пешеход', 'смотреть', 'туда']
# ['глаз', 'свой', 'поднять', 'пешеход', 'комментарий', 'увидеть', 'оправдывать', 'нигде', 'водитель', 'напоминать', 'обязанность', 'пешеход', 'пдд', 'убедиться', 'безопасность', 'переход']
# ['что', 'куку', 'лёд', 'дорога', 'наушник', 'вынемайк', 'сейчас', 'водить', 'виноватый', 'если', 'авто', 'тащить', 'абс', 'трещать']
# ['авто', 'абс', 'видео', 'видно', 'зад', 'занести']
# ['ку', 'ку', 'куку', 'а', 'знак', 'необходимо', 'соблюдать', 'и', 'гололёд', 'утверждать', 'а', 'далёкий', 'ехать', 'мало', 'пролететь', 'мимо']
# ['где', 'оно', 'ранний', 'наступление', 'весна']
# ['я', 'ждать', 'глобальный', 'потепления😬😬😬']
# ['не', 'нужно', 'писать', 'чушь', 'учёный', 'основа', 'пласт', 'антарктида', 'доказать', 'погода', 'наш', 'планета', 'цикличный', 'фаза', 'тепло', 'сменяться', 'фаза', 'холод', 'влияние', 'парниковый', 'эффект', 'выброс', 'фрион', 'идея', 'хотя', 'некоторый', 'цветок', 'стать', 'жить', 'стать', 'небо', 'стать', 'странный', 'цвет']
# ['наблюдать', 'сегодня', 'глобальный', 'потепление']
# ['быть', 'ждать', 'состояться', 'год']
# ['состоиться', 'половина', 'группа', 'заявить']
# ['тоже', 'увидеть', 'сейчас', 'загадывать', 'невозможно']
# ['сплин', 'думать', 'точно']
# ['жаль', 'зверь', 'луна', '🥺']
# ['а', 'вы', 'говорить', 'значит', 'точно']
# ['аргумент', 'точно', 'состояться']
# ['только', 'мочь', 'разогнать', 'артист', 'страна', 'возвращать', 'человек', 'деньга', 'фест', 'который', 'состояться']
# ['артист', 'сам', 'выбрать', 'свой', 'путь', 'свалить', 'поносить', 'россия', 'они', 'никто', 'выгонять']
# ['ахи', 'никто', 'иноагент', 'признавать']
# ['маленький', 'пиндеть', 'нужно']
# ['ты', 'стоить', 'прислушаться', 'он']
# ['думать', 'нужный', 'ваш', 'совет', 'считать', 'вообще', 'право', 'раздавать']
# ['деньга', 'возвращать', 'организатор', 'концерт', 'центробанк', 'это', 'возможно', 'любой', 'страна']
# ['это', 'должный', 'регламентировать', 'потребитель', 'должный', 'защитить']
# ['за', 'такой', 'параша', 'ещё', 'деньга', 'платить']
# ['тоже', 'возвращать', 'деньга', 'состаявшийся', 'концерт', 'чарджбек', 'успешно']
# ['король', 'шут', 'заценить', 'интересный', 'новость', 'узнать', 'хотеть']
# ['а', 'администрация', 'город', 'бийск', 'хотеть', 'спросить', 'почему']
# ['что', 'администрация', '🤔']
# ['согласование', 'снять', 'реклама', 'город', 'но', 'некто', 'далёкий', 'замарачиваться', 'стать']
# ['администрация', 'согласовать', 'место', 'дата', 'проведение', 'праздник', 'администрация', 'билет', 'рапространять', 'при', 'что', 'если', 'понять', 'привести', 'пример', 'вы', 'сдавать', 'квартира', 'квартиросъёмщик', 'решить', 'провести', 'лотерея', 'съёмный', 'квартира', 'сделать', 'билет', 'распродать', 'но', 'тираж', 'состояться', 'квартиросъёмщик', 'обмануть', 'деньга', 'уехать', 'отдыхать', 'граница', 'по', 'ваш', 'логика', 'обмануть', 'человек', 'должный', 'прийти', 'вы', 'вы', 'требовать', 'деньга', 'билет']
# ['а', 'всё', 'мочь', 'вернуть', 'деньга', 'концерт', 'шина', 'джихо', 'пп', 'ковид', 'отменять', 'знать', 'плакать']
# ['такой', 'проблема', 'купить', 'билет', 'джихо', 'вернуть', 'знать', '😭']
# ['мочь', 'списаться', 'лс', 'сообща', 'подумать', 'завтра', 'работа', 'мочь', 'ответ', 'неоклассик', 'поделиться', 'роспотребнадзор']
# ['ребята', 'новость', 'запоздалый', 'там', 'считать', 'хотеть', 'вернуть', 'вернуть', 'чарджбек', 'месяц', 'назад']
# ['некоторый', 'сей', 'пора', 'возвращать']
# ['да', 'спороть', 'просто', 'новость', 'звучать', 'это', 'первый', 'возврат']
# ['почему', 'отменить', 'концерт']
# ['знать', 'я', 'смотреть', 'баннер', 'казаться', 'зеленский', 'он']
# ['причина', 'фото', 'быт', 'очевидный', 'важно', 'окурок', 'это', 'опьянение', 'тупость']
# ['эл', 'плитка', 'возле', 'диван', 'зал', 'вы', 'смущать', '🤔']
# ['лечь', 'спать', 'сигарета', 'поджог', 'кровать']
# ['смущать', 'думать', 'хозяин', 'смущать', 'я', 'это', 'иметь', 'вид']
# ['сам', 'хозяин', 'элементарный', 'техника', 'безопасность', 'увы', 'соблюдать']
# ['сожаление', 'это', 'зал', 'обычный', 'комната', 'маласька']
# ['надеяться', 'котейка', 'спасти']
# ['вы', 'лично', 'знать', 'хозяин', 'квартира', 'знать', 'питомец']
# ['увидеть', 'лежанка', 'окно', 'животное', 'либо', 'кошка', 'либо', 'маленький', 'пёсик', 'знать', 'лично', 'соответственно', 'спросить', 'лично', 'возможно', 'ошибиться']
# ['ванночкудлить', 'купание', 'младенец', 'вы', 'увидеть', 'или', 'котейка', 'важный', 'человеческий', 'жизнь', '🤔']
# ['про', 'человек', 'написать', 'спасти', 'вообще', 'при', 'что', 'сравнение', 'ребёнок', 'животное', 'наравне', 'важный', 'никогда', 'делить']
# ['надеяться', 'всë', 'хорошо😢🙏']
# ['вчера', 'стуковый', 'видеть', 'дочь']
# ['ещё', 'фотография', 'новый']
# ['зря', 'шутить', 'браток']
# ['страшно', 'становиться', 'лицо', 'вид', 'адекватный', 'горожанин', 'немалый', 'количество', 'ходить', 'всякий', 'род', 'социопат', 'дегенерат', 'прочий', 'пидэрция']
# ['ты', 'социофоб', 'сделать', 'они', 'наооборот', 'бояться', 'человек']
# ['где', 'крайний', 'видеть', 'число', 'дата', 'место', 'время', 'чем', 'заниматься', 'увлекаться']
# ['не', 'такой', 'верить']
# ['конкретный', 'вопрос', 'кто', 'видеть', 'крайний', 'вопрос', 'сложный', 'просто', 'подумать', 'паника', 'спокойно', 'понимать', 'это', 'сложно']
# ['кто', 'крайний', 'выходить', 'связь', 'ветс', 'ап', 'соц', 'сеть']
# ['дарья', 'мать', 'пропасть', 'девушка']
# ['смочь', 'найти', 'её', 'хобби']
# ['🤷\u200d♀️🤷\u200d♀️🤷\u200d♀️человек', 'наверно', 'помочь', 'хотеть']
# ['найтись', 'живой', '😭🙏']
# ['наська', 'ждать', 'живой', '😭😭']
# ['точно', 'вернуться', '😭']
# ['это', 'мама', 'заходить']
# ['понятно', 'хоть', 'живой', 'найтись', 'девочка']
# ['админ', 'прям', 'юморист']
# ['он', 'просто', 'попасть', 'тёмный', 'сторона']
# ['да', 'снег', 'валита', 'начало', 'таить', 'подсыхать']
# ['офигеть', 'весёлый', 'картинка', 'прям', 'умора']
# ['девушка', 'весна', 'длинный', 'нога', 'спать', 'спокойный', 'сном…😥']
# ['четь', 'кот', 'кровь']
# ['весна', 'где', 'кошка', 'драться']
# ['а', 'сегодня', 'стукнуть', '😉']
# ['это', 'март', 'сибирь', 'это', 'нормально']
# ['весна', 'барнаул', 'апрель', 'начинаться']
# ['бывать', 'май', 'снег', 'пролетать']
# ['пролетать', 'пролетать', 'это', 'эпизод', 'тенденция']
# ['на', 'улица', 'холод', 'собачий', 'сегодня', 'весна', 'быть', 'речь', 'нету']
# ['климат', 'планета', 'просрали', '🔥🤔']
# ['рановато', 'ещё', 'весна']
# ['наташа', 'всё', 'уронили🤪']
# ['зарплата', 'расти', 'идти', 'туда', 'расти', 'мешать']
# ['жить', 'россия', 'барнаул', 'последний', 'несколько', 'год', 'зарплата', 'вырасти', 'раз']
# ['поздравлять', 'фото', 'свой', 'скрывать']
# ['фото', 'мой', 'нужно']
# ['говорить', 'платить', 'мало', 'это', 'водитель', 'скорый', 'который', 'давать', 'увольняйтеться', 'идти', 'нормально', 'оплачивать', 'работа']
# ['что', 'наивный', 'конкретно']
# ['алкаш', 'так', 'свой', 'жизнь', 'зарабатывать']
# ['по', 'весь', 'страна', 'проходить', 'митинг', 'именно', 'кпрф', 'именно', 'жкх', 'в', 'бийск', 'похоже', 'митинг', 'проходить', 'каждый', 'неделя', 'пермь', 'тюмень', 'ёбург', 'каменск', 'такой', 'ощущение', 'коммунист', 'спустить', 'разнарядка', 'дать', 'человек', 'стравить', 'пара', 'безопасный', 'тема']
# ['единый', 'россия', 'пойти', 'который', 'поднять', 'тариф', '🤣']
# ['пара', 'безопасный', 'тема', 'извинить', 'это', 'легальный', 'полулегальный', 'борьба', 'обращение', 'акция', 'прочее', 'это', 'способ', 'скооперировать', 'народ', 'важно', 'правильный', 'русло']
# ['жкх', 'цена', 'билет', 'трамвай', 'так', 'п', 'это', 'безопасный', 'тема', 'а', 'свобода', 'слово', 'сво', 'политзаключённый', 'сменяемость', 'власть', 'честной', 'выборы', 'коррупция', 'тема', 'запрет', 'коммунист', 'мочь', 'легко', 'понять', 'выбор', 'протестный', 'повестка', 'никто', 'хотеть', 'выпасть', 'окно', 'в', 'принцип', 'иметь', 'против', 'активность', 'узкий', 'дозволить', 'диапазон', 'метод', 'тема', 'рамка', 'короткий', 'список', 'организация', 'который', 'дозволить']
# ['на', 'фон', 'руина', 'исторический', 'здание', 'душевно', 'российски']
# ['знать', 'коммунизм', 'это', 'зарабатывание', 'деньга', 'это', 'отобрать', 'один', 'дать', 'немного', 'другой', 'оставить', 'карман', 'неплохой', 'комиссия']
# ['коммунизм', 'это', 'каждый', 'способность', 'каждый', 'потребность', 'почитать', 'думать', 'человечество', 'скоро', 'этот', 'дойти']
# ['больший', 'деньга', 'украсть', 'а', 'заработать', 'а', 'заработать', 'шура', 'геморрой']
# ['тот', 'работать', 'работать', 'тот', 'потреблять', 'потреблять', 'весело', 'придумать', 'тот', 'потреблять']
# ['комунизьма', 'это', 'пристанище', 'нищий', 'никчёмный', 'человек', 'никак', 'жизнь', 'реализовать']
# ['советский', 'власть', 'часовой', 'рабочий', 'день', 'установить', 'оплачивать', 'отпуск', 'больничный', 'декретный', 'отпуск', 'а', 'капитализм', 'пахать', 'дядя', 'ребёнок', 'при', 'советский', 'власть', 'возраст', 'выход', 'пенсия', 'рыночный', 'экономика', 'оживление', 'бот', 'очередной', 'подтверждать', 'митинг', 'пройти', 'отлично', 'уже', 'федеральный', 'канал', 'он', 'написать']
# ['это', 'пытаться', 'объяснить', 'константин', 'пидоренко', 'первый', 'фамилия', 'говорящий', 'второй', 'оно', 'просто', '💩по', 'жизнь']
# ['пытаться', 'объяснять', 'давно', 'понять', 'обиженный', 'детство', 'пионер', 'несчастный', 'хохол']
# ['совковый', 'власть', 'пахать', 'трудодень', 'расчёт', 'кг', 'пшеница', 'трудодень', 'в', 'какой', 'год', 'колхозник', 'совка', 'стать', 'получать', 'пенсия', 'какой', 'размер']
# ['кровать', 'ватюня', 'проверить', 'хохол', 'сидеть']
# ['жкх', 'ответ', 'нет', '🤣🤣🤣']
# ['собака', 'лаять', 'караван', 'идти']
# ['правильно', 'особенно', 'партия', 'единый', 'россия', 'распустить', 'пенсия', 'индексировать', 'страна', 'смешно', 'старик', 'добавка', 'вова', 'жить', 'выживать', 'особенно', 'сегодняшний', 'время', 'цена', 'продукт', 'тариф', 'жкх', 'вырасти']
# ['судно', 'воздушный', 'подушка', 'который', 'выделить', 'правительство', 'алтайский', 'край', 'специально', 'перевозка', 'человек', 'период', 'межсезонье', 'ответ', 'судно', 'воздушный', 'подушечка', 'находиться', 'кармашек', 'чиновничка']
# ['у', 'сегодня', '«каталось»', 'жилой', 'модуль', 'тащить', 'ток', 'тот', 'сторона']
# ['бл', 'дь', 'ну', 'неужели', 'мост', 'построить', 'место', 'ведь', 'один', 'село', 'берег', 'река', 'находиться', 'а', 'человек', 'понадобиться', 'скорый', 'помощь', 'быстрый', 'умереть', 'приехать', 'крымский', 'построить', 'проблема', 'а', 'обычный', 'местный', 'невозможно']
# ['карлина', 'ответить', 'построить', 'экономический', 'целесообразность']
# ['год', 'томенко', 'край', 'заправлять', 'хотя', 'ещё', 'плохой', 'карлина', 'глянуть']
# ['дорога', 'новый', 'построить', 'наш', 'томенко', 'качество', 'стать']
# ['дорога', 'начать', 'делать', 'ещё', 'карлина', 'го', 'год', 'вы', 'известно', 'это', 'заслуга', 'томенко', 'раз']
# ['ленточный', 'двор', 'расширить', 'попов', 'расширить', 'дорога', 'затон', 'обновить', 'солнечный', 'полянин', 'дорога', 'положить', 'всё', 'нынешний', 'губернатор']
# ['видно', 'человек', 'столбовый', 'например', 'камень', 'добираться', 'ну', 'видно', 'значит', 'проблема', 'вроде', 'нет🤷\u200d♂️', 'маразм', 'натуральный', 'дурд', 'век', 'нанотехнология', 'млять😡']
# ['зато', 'томенко', 'филармония', 'хоккей', 'сходить']
# ['великий', 'страна', 'европа', 'точно', 'завидовать']
# ['аж', 'нога', 'свести']
# ['а', 'тот', 'сторона', 'находиться', 'станция', 'плотинный', 'который', 'относиться', 'город', 'вот', 'отдалить', 'район', 'город']
# ['разуваться', 'промочииться', 'оставаться', 'сухой', 'разуться', 'бред', '✌🤔😳😲🙄🤧']
# ['судно', 'видеть', 'рыбалка', 'некогда', 'всякий', 'хня', 'заниматься', 'послёдний', 'лёд', 'ловчий', 'самый']
# ['о', 'нормальный', 'дело', 'ребята', 'заниматься', 'жаль', 'сила', 'рассчитать']
# ['сейчас', 'выползти', 'авторитетный', 'уж', 'рассказать', 'весь', 'сколько', 'деньга', 'взять', 'родитель', 'спасение', 'ребёнок', 'чтоб', 'впредь', 'лазить', 'попасть', 'спокойно', 'тупить', 'телефон', 'диван']
# ['сбиться', 'путь', 'стать', 'рисковать', 'да', 'этот', 'ребёнок', 'мозг', 'взрослый']
# ['как', 'такой', 'больший', 'ребёнок', 'заблудиться', 'гора', 'это', 'лес', 'мы', 'малый', 'возраст', 'ходить', 'гора', 'нормально']
# ['какой', 'по', 'который', 'ледянка', 'спускаться', 'так', 'это', 'гора🤷\u200d♂️']
# ['внимательно', 'прочитать', '🤷\u200d♀️']
# ['что', 'это', 'ребёнок', 'который', 'спуститься', 'смочь']
# ['спускаться', 'сложно', 'гравитация', 'сделать', '😅']
# ['я', 'вырасти', 'тот', 'место', 'телефон']
# ['в', 'парилка', 'металл', 'сразу', 'видно', 'хороший', 'тёплый', 'место']
# ['место', 'отдых', 'забыть', 'показать']
# ['на', 'горка', 'полетать', 'бы🤣🤣🤣🤣']
# ['март', 'отдыхать', 'семья', 'очень', 'понравиться', 'классно']
# ['вредитель', 'жилец', 'расселить']
# ['застройщик', 'очищать', 'територий', 'дешёвый', 'выйти', 'сносить', 'вывозить']
# ['конечно', 'сделать', 'улица']
# ['вырасти', 'спрос', 'полугнилой', 'летний', 'дерево']
# ['это', 'хороший', 'дерево', 'ведь', 'поверженный', 'гниль', 'вообще', 'сруб', 'стоять', 'триста', 'год']
# ['дерзать', 'скупать', 'что', 'сидеть', 'вы', 'видимо', 'бизнесмен', 'опытный', 'знать', 'большой', 'остальной']
# ['сгореть', 'а', 'бизнесмен', 'мало', 'знать', 'программа', 'купить', 'перепродать', 'лапша', 'ухо', 'навещать', 'а', 'знать', 'остальной', 'образовать', 'а', 'мома', 'пост', 'достаточно', 'пример', 'пообщаться', 'опытный', 'строитель', 'время', 'ссср', 'жаль', 'мало']
# ['всё', 'ещё', 'куча', 'такой', 'дом', 'город', 'всё', 'ваш', 'рука', 'посмотреть', 'сколько', 'живой', 'дерево', 'оттуда', 'добыть']
# ['лес', 'пока', 'распилить', 'цепь', 'пил', 'разориться', 'там', 'песок', 'гвоздь', 'лес', 'тяжело', 'пилиться', 'так', 'выгодно', 'логистика', 'разбор', 'затратешиться']
# ['сам', 'загореться', 'очевидный', 'же🤣']
# ['ждать', 'новый', 'трц', 'дом']
# ['новый', 'департамент', 'контроль', 'незаконный', 'оборот', 'пенсия', 'социальный', 'выплат😉']
# ['деревянный', 'сухой', 'спичка', 'сгореть', 'минута', 'весь', 'пепел', 'остаться']
# ['дерево', 'перекрытие', 'перегородка', 'стена', 'кирпичный']
# ['он', 'разобрать', 'весь', 'кровля', 'там', 'хлам', 'видимо', 'вывозить', 'прийтись', 'сгореть', 'сгореть']
# ['да', 'поверхность', 'лежать', 'за', 'разборка', 'нужно', 'платить', 'вывоз', 'прочее', 'пожар']
# ['лы', 'наверное', 'поджечь', 'думать', 'военкомат']
# ['купить', 'колесо', 'нива']
# ['два', 'шина', 'один', 'вли', 'новый', 'запаска', 'второй', 'кама', 'вроде', 'безкамерный', 'слой', 'работать', 'камера', 'нужно', 'ставить']
# ['вроде', 'колесо', 'сбор']
# ['нужный', 'комплект', 'грязевый']
# ['делать', 'заказ', 'обложка', 'паспорт', 'натуральный', 'кожа', 'ручной', 'работа✅️', 'не', 'дорого']
# ['кружка', 'ручной', 'работа', 'дизайн', 'выбор']
# ['здравствуйте', 'руб', 'зависимость', 'сложность', 'дизайн']
# ['декор', 'ручной', 'работа', 'дизайн', 'выбор']
# ['делать', 'заказ', 'портмоне', 'размер', '×', 'сложить', 'вид', 'ручной', 'работа', 'натуральный', 'кожа✅️']
# ['детский', 'термоковрик', 'наличие', 'руб']
# ['матрац', 'медицинский', 'абсолютно', 'новый', 'цена']
# ['делать', 'заказ', 'обложка', 'паспорт', 'в', 'у', 'натуральный', 'кожа', 'ручной', 'работа✅️']
# ['прохожий', 'мимо', 'мужчина', 'журналист', 'алтапресс', 'публикация', 'перечитывать', 'написать']
# ['думать', 'двач', 'репост']
# ['редактор', 'смотреть', 'видеть', 'вместо', 'буква', 'неведомый', 'закорючка', 'он', 'спрашивать', 'чукча', 'читать', 'вообще', 'уметь', 'чукча', 'однако', 'читатель', 'чукча', 'писатель', '😉']
# ['что', 'причудливый', 'прохожий', 'мимо', 'мужчина']
# ['поколение', 'егэ', 'устроиться', 'работа']
# ['нееросеть', 'новостит', 'постит']
# ['а', 'удосужиться', 'помочь', 'снимать', 'стоять', 'равнодушно']
# ['поколение', 'тиктокер', 'что', '🤷😞']
# ['прошлый', 'пост', 'отписываться', 'парень', 'молодец', 'просто', 'раскидать', 'гореть', 'палета', 'тиктокер', 'ждать', 'пока', 'разгореться', 'поди', 'поджечь']
# ['возможно', 'жить', 'дом', 'рядом', 'видеть', 'курить', 'а', 'снимать', 'автор', '«курилка»']
# ['мимо', 'прохожий', 'чей', 'общество', 'вхожий', 'двигать', 'паллет', 'огонь', 'бояться', 'дело', 'закончить', 'позвать', 'дочка', 'вдаль', 'уходить', 'отряхнуть', 'длань']
# ['это', 'мужчина', 'похоже', 'гореть', 'пусть', 'гореть', 'пройти', 'мимо', 'поджог', 'обвинить']
# ['пусть', 'гореть', 'поддон', 'лёд', 'растаять']
# ['этот', 'проблема', 'мой', 'память', 'год']
# ['ещё', 'год', 'пять', 'назад', 'такой', 'помнить']
# ['ну', 'аккуратно', 'лежать']
# ['так', 'уютный', 'домашний', 'фекалия', 'помои', 'нищета']
# ['это', 'посмотреть', 'европа', 'происходить', 'вообще', 'мусор', 'утопать', 'забастовка', 'газ', 'отключить']
# ['помёрзнуть', 'пустой', 'улица', 'обледенеть', 'статуя', 'бывший', 'человек']
# ['давать', 'учиться', 'сортировать', 'мусор', 'понемногу', 'главное', 'начать', 'тогда', 'стать', 'понятно', 'сколько', 'мусорить', 'прийти', 'понимание', 'стремиться', 'малый', 'ненужный', 'упаковка']
# ['вопрос', 'сортировать', 'если', 'увозить', 'перерабатывать', 'никто', 'заниматься', 'дать', 'ситуации🤦\u200d♂️']
# ['давать', 'вывозить', 'начало', 'начать']
# ['дело', 'вывозить', 'кол', 'мусор', 'год', 'год', 'расти', 'поэтому', 'учиться', 'утилизировать', 'сортировать', 'просто', 'вывозить', 'глаз', 'долой']
# ['сортировать', 'куча', 'мусор', 'никто', 'вывозить', 'гнить', 'улица']
# ['сортировать', 'сдавать', 'переработка', 'если', 'вы', 'отсортировать', 'сдать', 'переработка', 'переработать', 'куча', 'мусор', 'быть', 'маленький', 'раз', 'потом', 'быть', 'думать', 'избегать', 'лишний', 'мусор', 'упаковка', 'пакет', 'так', 'далее', 'переходить', 'возможно', 'многоразовый', 'вещь', 'ссылка', 'алексей', 'действительно', 'интересоваться', 'просто', 'писать', 'комментарий', 'пожаловаться', 'плохо', 'никто', 'вывозить', 'мусор']
# ['давать', 'сортировать', 'ага', 'у', 'балкон', 'завалить', 'мытый', 'пластик', 'месяц', 'пока', 'эко', 'такси', 'приезжать', 'пара', 'хватить', 'это', 'дело', 'послать', 'нафиг', 'нужно', 'ставить', 'бак', 'сразу', 'дом', 'хранить', 'шляпа', 'дом', 'месяц']
# ['знакомый', 'бак', 'пластика', 'окно', 'общий', 'бак', 'весь', 'мусор', 'кидать', 'аргумент', 'кто', 'быть', 'сортировать', 'тот', 'забирать', 'пластик', 'сдавать', 'деньга', 'делать', 'бесплатно', 'должный', 'сортировать']
# ['кто', 'это', 'чтобы', 'сортировать', 'нужный', 'развить', 'инфраструктура', 'сбор', 'мусор', 'а', 'мусоровоз', 'ходить', 'двор']
# ['вы', 'подумать', 'обязательно', 'найти', 'ответ', 'свой', 'вопрос', 'кто', 'это']
# ['так', 'мусорный', 'контейнер', '🤔', 'или', 'потоковский', 'свинья', 'выкидывать', 'мусор', 'везде', 'вздуматься', 'должный', 'ходить', 'убирать', 'они']
# ['контейнер', 'видно', 'вывозить']
# ...
# ['трактор', 'прокормить', 'человек', 'рубцовск']
# ['лиза', 'беда', 'начало', '🤷', 'есть', 'идея', 'предлагать']
# ['х', 'понять', 'выглядеть', 'привлекательно', 'так', 'идея']
# ['идея', 'говно', 'баня', 'а', 'бизнес', 'план', 'стоить', '€']
# ['ахи', 'додуматься', 'толстый', 'ведущий', 'красный', 'горошек', 'нарядить🤣🤣']
# ['думать', 'свой', 'ходить', 'работа']
# ['пазик', 'мнение', 'репортёр', '☺']
# ['год', 'ручной', 'сборка', 'поход', 'стоить', 'должный', 'ламб']
# ['качество', 'типовой', 'кондиционер', 'кулер', 'вода', 'панорамный', 'крыша', 'газокалотурбинный', 'мотор', 'главное', 'ноу', 'хау', 'дворник', 'причём', 'постоянный', 'основа', 'жэу']
# ['отлично', 'ещё', 'опробовать', 'дело', 'довести', 'совершенство', 'надёжно', 'просто']
# ['какой', 'машина', 'кто', 'хотеть', 'спасать', 'скоро', 'лес', 'вообще']
# ['по', 'один', 'машина', 'месяц', 'а', 'вездеход', 'лес', 'дерево', 'проехать']
# ['на', 'попов', 'авария', 'сеть', 'устранять']
# ['маленький', 'счёт', 'жкх', 'плохо']
# ['глупый', 'тупой', '🤔']
# ['счёт', 'немного', 'маленький']
# ['думать', 'ремонт', 'наш', 'счёт']
# ['на', 'антон', 'петров', 'день', 'вода', 'отопление', 'администрация', 'сказать', 'ночью', 'должный', 'дать', 'вчера', 'говорить']
# ['невский', 'отопление', 'вода', 'кран', 'тёплый']
# ['энтузиаст', 'куковать', 'отопление', 'а', 'день', 'дом', 'остывать', 'начать', 'реально', 'дубак', 'начаться']
# ['советский', 'армия', 'вчерашний', 'день']
# ['то', 'дом', 'отключить', 'это', 'враньё', 'гораздо']
# ['год', 'ссср', 'второй', 'день', 'еле', 'живой', 'батарея']
# ['почему', 'георгиев', 'сухэ', 'батор', 'отопление', 'горячий', 'вода']
# ['если', 'коротко', 'плата', 'отопление', 'удвоить', '😎']
# ['а', 'насторожить', 'последний', 'предложение', '😳']
# ['главное', 'никак', 'яровой']
# ['если', 'работа', 'сделать', 'очень', '🤦\u200d♂️']
# ['про', 'какой', 'котельная', 'речь']
# ['ага', 'профессия', 'зависиль', 'спортивный', 'навык', 'не', 'попадать', 'школа', 'кольцо', 'всё', 'видеограф', 'фотограф', 'а', 'пас', 'нормальный', 'дать', 'неумелый', 'перекуп']
# ['мочь', 'обратить', 'внимание', 'министерство', 'министр']
# ['простить', 'удержаться', 'реально', 'водитель', 'носить', 'пациент', 'лично', 'помнить', 'грубый', 'форма', 'отказывать', 'бригада', 'состав', 'фельдшер', 'девушка', 'помощь', 'родственник', 'бегать', 'искать', 'подъезд', 'бабушка', 'вынести', 'мочь', 'измениться', 'год', 'водитель', 'реально', 'стать', 'помогать']
# ['некоторый', 'носить', 'некоторый']
# ['ранний', 'просто', 'водитель', 'получать', 'переноска', 'носилочный', 'ставка', 'санитар', 'этот', 'деньга', 'растереться', 'получиться']
# ['год', 'назад', 'улица', 'метаться', 'просить', 'помощь', 'множество', 'человек', 'дело', 'важный', 'водитель', 'выдержать', 'мой', 'отчаяние', 'оставить', 'присматривать', 'автомобиль', 'пойти', 'выносить', 'мой', 'отец', 'мысленно', 'сей', 'пора', 'благодарить', 'это']
# ['раз', 'видеть', 'водитель', 'носить', 'больной', 'наверное', 'еденичный', 'случай']
# ['скорее', 'я', 'поделиться', 'свой', 'опыт', 'это', 'бортовый', 'номер', 'весь', 'бригада', 'быть', 'помнить', 'долго']
# ['дело', 'добровольный', 'основное', 'носить', 'особенно', 'село']
# ['зато', 'бывший', 'топ', 'менеджер', 'норникель', 'год', 'медучреждение', 'отремонтировать', 'наверное', 'шуруповерт', 'бегать']
# ['попов', 'выгнать', 'красноярск', 'пост', 'помогать', '🤣']
# ['убежать', 'наказание', 'голубка']
# ['статья', 'фейк', 'по', 'телевизор', 'мы', 'другой', 'рассказывать']
# ['жесть', 'как', 'прожить', 'это', 'еда', 'проезд', 'хватит…', 'ещё', 'коммуналка', 'золотой', 'идти', 'таксист', 'при', 'графика', 'работа', 'раз', 'заработать…', '…', 'мочь', 'начальство', 'призадуматься', 'уволиться', 'пойти', 'таксовать…', 'но', 'простой', 'человек', 'пострадают…']
# ['жить', 'многие', 'работать', 'работа']
# ['машина', 'скорый', 'помощь', 'управлять', 'кто', 'помощь', 'вы', 'привезти', 'доктор', 'такси']
# ['вообще', 'слепой', 'тупой', 'последний', 'предложение', 'написать']
# ['манер', 'общение', 'незнакомый', 'человек', 'вы', 'смотреть', 'занимать']
# ['лишь', 'зацепиться', 'придраться', 'что', 'жаль', 'проканать', 'ибо', 'сказать']
# ['как', 'показывать', 'практика', 'обращение', 'гражданин', 'против', 'пенсионный', 'возраст', 'повышение', 'цена', 'жкх', 'и', 'так', 'далее', 'результат']
# ['завтра', 'заставить', 'извиняться']
# ['путин', 'высокий', 'чиновник', 'государство', 'государство', 'рука', 'правящий', 'класс', 'крупный', 'капитал', 'плевать', 'беда', 'чаяние', 'простой', 'работяга', 'только', 'забастовка', 'стачки‼']
# ['это', 'рука', 'внешний', 'сила', 'на', 'место', 'этот', 'человек', 'просто', 'уволиться', 'задуматься', 'здоровый', 'мужчина', 'город', 'заработать']
# ['здоровый', 'пьющий', 'безработный', 'год']
# ['человек', 'находиться', 'отчаянный', 'положение', 'работа', 'россия', 'нет‼']
# ['извинить', 'жить', '😳']
# ['скорее', 'з', 'п', 'жена', 'мамкин', 'пенсия', 'пока', 'ждать', 'достойный', 'работа']
# ['такой', 'к', 'сожаление']
# ['очень', 'работать', 'соц', 'служба', 'иметь', 'дело', 'безработный', 'такой', 'здоровый', 'пьющий', 'безработный', 'год', 'работать', 'десятка', 'год', 'поработать', 'пара', 'месяц', 'бежать', 'пособие', 'практически', 'каждый', 'второй', 'а', 'предлагать', 'работа', 'очень', 'оскорбляться', 'кричать', 'я', 'работа', 'найти', 'вы', 'пособие', 'назначать']
# ['обычный', 'история', 'работать', 'сфера', 'который', 'иметь', 'малый', 'представление', 'поработать', 'шинный', 'флипперофшица', 'пол', 'год', 'хотя', 'консиб', 'обрезинка', 'постоять', 'посмотреть', 'запеть']
# ['сам', 'таскать', 'они', 'конь', 'многий', 'спина', 'сорванна']
# ['много', 'труд', 'шофер', 'цениться']
# ['шнекоротор', 'судьба', 'пустить']
# ['лишь', 'трахтур', 'мужик', 'лопата']
# ['это', 'значит', 'обь', 'вода']
# ['погода', 'зависеть', 'интенсивно', 'таять', 'скорее']
# ['трактор', 'свежий', 'какойтый']
# ['агромаш', 'тг', 'современный', 'дт']
# ['кабина', 'капот', 'свежий']
# ['такой', 'тракторишка', 'мудрено', 'дорога', 'село', 'неделя', 'чистить']
# ['сейчас', 'быдлан', 'быть', 'массово', 'возмущаться', 'мол', 'ставить', 'свой', 'ведро']
# ['почему', 'это', 'должный', 'кто', 'волновать']
# ['сударь', 'сенсеять', 'комментарий']
# ['знак', 'препинание', 'выйти', 'чат']
# ['ой', 'ещё', 'возле', 'магазин', 'светофор', 'сова', 'армия', 'проехаться', 'ни', 'пройти', 'проехать', 'магазин', 'открыть', 'парковка', 'обеспечить', 'парковаться', 'хотеть', 'хотеть']
# ['напротив', 'светофор', 'случаем', 'должное', 'орган', 'забавно', 'тот', 'видеть', 'проблема']
# ['дорога', 'ленинский', 'район', 'это', 'надо😃']
# ['осуждать', 'парковка', 'неположенный', 'место', 'логан', 'нарушить', 'по', 'фото', 'понятно', 'это', 'газон', 'тротуар', 'часть', 'проезд', 'вдоль', 'дом']
# ['второй', 'фото', 'чётко', 'видно', 'стоять']
# ['на', 'первый', 'фото', 'бордюр', 'вообще', 'друг', 'место', 'сфотали…']
# ['рейд', 'двор', 'пройти', 'предмет', 'очистка', 'снег', 'лёд', 'это', 'весь', 'увидеть', 'бордюр', 'песочница', 'забор', 'дерево', 'киоск', 'роспечать', 'на', 'улица', 'тепло', 'стоить', 'ручей', 'литься', 'день', 'блуждание', 'город', 'один', 'трактор', 'двор', 'увидеть', 'зато', 'пройти', 'проехать', 'дерьмо', 'собачий', 'оттаять', 'болото', 'каток', 'самый', 'главное', 'сам', 'жилец', 'молчать', 'видимо', 'всё', 'устраивать', 'свой', 'ук']
# ['видеть', 'они', 'нечего', 'делать', '🤷\u200d♂️', 'экскаватор', 'брать', 'лёд🤦\u200d♂️', 'фронтальник', 'вообще', 'нечего', 'делать', 'буксовать', 'оторвать', 'нечего', 'может🤷\u200d♂️', 'грейдер', 'везде', 'брать', 'лёд', 'гидромолотый', 'асфальт', 'изорвать', 'весь', 'пока', 'земля', 'отойти', 'лёд', 'отщёлкиваться', '🤷\u200d♂️', 'земля', 'нынче', 'промёрзлый']
# ['логан', 'нарушить', 'иногда', 'ходить', 'парковка', 'далёкий', 'фото', 'видно', 'машина', 'стоять', 'тротуар', 'там', 'детский', 'сад', 'родитель', 'ребёнок', 'пройти', 'невозможно', 'парковка']
# ['если', 'бордюрный', 'камень', 'визуально', 'видно', 'нарушение', 'всё', 'вопрос', 'очистка', 'тротуар', 'дорога']
# ['включать', 'дурачок', 'такой', 'гора', 'водятел', 'видно', 'дорожка', 'снег']
# ['формально', 'отмазаться', 'факт', 'человек', 'прекрасно', 'понимать', 'это', 'тротуар', 'поверить', 'первый', 'заехать', 'лето', 'парковаться', 'прекрасно', 'видно', 'почему', 'думать', 'зимой', 'газон', 'парковаться', 'двойной', 'сплошной', 'пересекать', 'видно', 'снег', 'хотя', 'человек', 'ездить', 'один', 'маршрут', 'знать', 'нарушать']
# ['обязательный', 'делать', 'рейд', 'обычный', 'потрулирование', 'следить', 'порядок', 'соблюдение', 'правило', 'разве', 'это', 'входить', 'ежедневный', 'обязанность', 'гибдд']
# ['бухой', 'ловить', 'осаго', 'ездить']
# ['хороший', 'уборка', 'снег', 'заняться', 'венеция', 'место', 'город']
# ['а', 'смотреть', 'штаны', 'написесть', 'докапываться']
# ['хороший', 'машина', 'парковаль', 'нужно', 'убирать', 'снег', 'а', 'венеция', 'место', 'город']
# ['что', 'заметно', 'логан', 'тротуар', 'стоить']
# ['именно', 'стоить', 'каждый', 'день', 'нужно', 'ранний', 'ехать', 'штука', 'увезти']
# ['сказать', 'эвакуатор', 'снова', 'появиться', 'работёнка', 'место', 'стоить', 'газель']
# ['сказать', 'один', 'порисоваться', 'хватить']
# ['эвакуатор', 'реально', 'мышь', 'тырить', 'машина', 'сьебывают…', 'крыса']
# ['вы', 'видеть', 'что', 'произойти', 'на', 'попов']
# ['попов', 'приехать', 'скорый', 'полиция', 'друг', 'подробность', 'знать', 'видео']
# ['рассказать', 'новость', 'мочь', 'снять', 'близкий', 'жить', 'этаж']
# ['будущий', 'сосед', 'попов', 'приветствовать', '🥰']
# ['что', 'у', 'кто', 'на', 'чистить']
# ['возможно', 'припадок', 'человек', 'эпилепсия']
# ['😎', 'норма', 'молодец']
# ['хорошо', 'инициативный', 'человек', 'наш', 'город', 'молодец']
# ['наш', 'улица', 'почистить', 'туда', 'обратно', 'трактор', 'проехать']
# ['чистый', 'четверг', 'надо', 'придумать', 'там', 'ещё', 'страстный', 'пятница', 'прощёный', 'воскресение']
# ['ну', 'говорить', 'аванесов', 'приехать', 'трактор', 'камаз', 'тонар', 'вывезти', 'разворошить', 'метр', 'сугробик']
# ['судить', 'весь', 'первый', 'зиму🤣🤣🤣']
# ['для', 'який', 'завдань', 'це', 'робиться', 'чий', 'вонь', 'хочуть', 'цим', 'досяготь']
# ['киев', 'войти', 'проблема', 'вот']
# ['зачем', 'мы', 'это', 'понимать', 'сво', 'другой', 'орган', 'работать']
# ['хороший', 'подоражание', 'тариф', 'пусть', 'рассказать', 'сразу', 'р']
# ['здравствуйте', 'мы', 'действительно', 'пересмотреть', 'условие', 'некоторый', 'наш', 'архивный', 'тариф', 'изменение', 'связать', 'затрата', 'компания', 'время', 'увеличиваться', 'хотеть', 'сохранять', 'высокий', 'качество', 'связь', '💚']
# ['мегафон', 'скатиться', 'месяц', 'снимать', 'абонентский', 'плата', 'плюс', 'каждый', 'день', 'р', 'за', 'интернет', 'безлимитный', 'год', 'немой', 'пора', 'менять', 'оператор']
# ['здравствуйте', 'просить', 'спешить', 'принимать', 'решение', 'смена', 'оператор', '🙏', 'написать', 'пожалуйста', 'мы', 'личный', 'сообщение', 'помочь', 'весь', 'разобраться', '💚']
# ['смотреть', 'нужно', 'доп', 'услуга']
# ['значит', 'смотреть', 'условие', 'тариф', 'поменяться', 'хотеть', 'оставаться', 'хотеть', 'валить']
# ['это', 'вкрутить', 'доп', 'услуга', 'согласие', 'мегафон', 'первый', 'место', 'среди', 'я', 'пользованый', 'самый', 'классный', 'позвонить', 'оператор', 'предложить', 'перейти', 'новый', 'тариф', 'архивный', 'обещать', 'течение', 'х', 'месяц', 'быть', 'подключать', 'втихаря', 'услуга', 'есть', 'один', 'симка', 'роутер', 'она', 'естественно', 'никто', 'позвонить', 'туда', 'вкрутить', 'услуга', 'гудок']
# ['кстати', 'сколько', 'говорить', 'это', 'год', 'такой']
# ['современный', 'человек', 'у', 'смартфон', 'стоить', 'приложение', 'мегафон', 'функция', 'так', 'ч', 'просматривать', 'подписка', 'смартфон', 'родственник', 'какой', 'добавить', 'номер', 'телефон', 'лк', 'видно', 'добавить', 'семья', 'общаться', 'быть', 'бесплатно']
# ['год', 'назад', 'уйти', 'жалеть', 'раз', 'жалеть', 'чёрт', 'дрявыя']
# ['приятель', 'какой', 'подписка', 'симка', 'который', 'автосигнализация', 'стоить', 'вкорячить', 'причём', 'прийти', 'разбираться', 'прям', 'божиться', 'человек', 'друг', 'конец', 'провод', 'чётко', 'отвечать', 'да', 'предложение', 'подписать', 'естественно', 'сюрприз', 'симка', 'сигналка', 'стоить', 'приберечь', 'финал', 'финал', 'удаться']
# ['пока', 'мегафон', 'команда', 'подписокнуть', 'спасать', 'только', 'регулярный', 'проверка', 'личный', 'кабинет', 'предмет', 'новенький']
# ['обосраться', 'всякий', 'мегафон', 'мтс', 'билайна', 'каждый', 'оператор', 'тариф', 'перевод', 'остаток', 'новый', 'месяц', 'быстро', 'слететь', 'ждать', 'сфера', 'соснуть', 'больший', 'ка', 'быть', 'заманивать']
# ['посмотреть', 'важный', 'нормальный', 'связь', 'перенос', 'деньга', 'пока', 'это', 'увидеть', 'ток', 'мтс']
# ['купить', 'всякий', 'кредит', 'пр', 'хни']
# ['мама', 'наверное', 'деньга', 'дать']
# ['взрослый', 'мальчик', 'конец', 'март', '🤣😉']
# ['про', 'мегафон', 'у', 'тариф', 'конец', 'месяц', 'день', 'окончание', 'месяц', 'неожиданно', 'заканчиваться', 'пакет', 'фишка', 'сразу', 'предлагаться', 'подключать', 'доп', 'гб', 'инэта', 'доп', 'сумма', 'итак', 'каждый', 'месяц', 'прийтись', 'перейти', 'другой', 'оператор']
# ['да', 'дом', 'разрушаться', 'да', 'дом', 'шпиль', 'зайти', 'сильно', 'удивиться']
# ['это', 'туда', 'турист', 'водить', 'там', 'весь', 'россия', 'лицевой', 'сторона', 'показуха', 'сзади', 'сам', 'дело']
# ['свежий', 'мочь', 'ремонт', 'проводить', 'фотографировать', 'поса', 'свежий', 'фото', 'соседний', 'дом', 'студия', 'особенно', 'который', 'слева', 'смотреть', 'первый', 'фотография']
# ['нету', 'который', 'слева', 'первый', 'фото', 'второй', 'фото', 'собственно', 'пост', 'видеть', 'фото', 'протекать', 'кровля', 'вода', 'бежать', 'стена', 'здание', 'разрушать', 'фасад', 'это', 'здание', 'разваливаться', 'это', 'бездействие', 'управлять', 'компания', 'ремонт', 'кровля', 'либо', 'её', 'неправильный', 'конструкция']
# ['да', 'воровайка', 'делать']
# ['а', 'человек', 'жить']
# ['кто', 'знать', 'оно', 'весна', 'оттаять', 'осень', 'вроде', 'совесть', 'приморозить']
# ['вставить', 'бутафорский', 'окно', 'барак', 'выселить', 'да', 'сдавать', 'аренда', 'пока', 'снести']
# ['ещё', 'жилой', 'крайний', 'мера']
# ['здравствуйте', 'указать', 'пожалуйста', 'адрес', 'дом', 'который', 'идти', 'речь', 'передать', 'информация', 'профильный', 'специалист']
# ['здравствуйте', 'спасибо', 'уточнение', 'передать', 'информация', 'фото', 'комитет', 'жкх', 'ответ', 'специалист', 'сообщить', 'март']
# ['ну', 'жалко', 'такой', 'красивый', 'дом', 'почему', 'оказаться', 'такой', 'состояние']
# ['здание', 'срок', 'эксплуатация', 'рано', 'поздно', 'заканчивается…']
# ['добрый', 'день', 'специалист', 'готовить', 'ответ', 'ваш', 'вопрос', 'связаться', 'вы']
# ['а', 'сколько', 'закрыть']
# ['такой', 'сказка', 'рассказывать', 'не', 'больница', 'жуть', 'плоть', 'разворовать', 'страна', 'скот']
# ['украина', 'рени', 'это', 'одесса']
# ['взаимосвязанный', 'сво', 'количество', 'отремонтировать', 'лечебный', 'учреждение', 'ты', 'поставить', 'задача', 'хрюкать', 'каждый', 'пост']
# ['про', 'гордость', 'повод', 'фап', 'в', 'новосибирский', 'область', 'тысяча', 'сельский', 'население', 'приходиться', 'фап', 'алтайский', 'край', 'тысяча', 'сельский', 'население', 'фап', 'так', 'доступность', 'медицина', 'село', 'край', 'ниже', 'плинтус']
# ['что', 'барак', 'бехтерев', 'он', 'попасть']
# ['разрушать', 'разрушать', 'оптимизировать', 'теперь', 'востановить', 'решить', 'медаль', 'герой', 'и', 'на', 'доска', 'почёт', 'спаситель', 'наш', 'и', 'кормилец']
# ['в', 'барнаул', 'хороший', 'краевой', 'больница', 'многие', 'сюда', 'ехать', 'бесплатно', 'делать', 'дорогостоящий', 'операция', '👏']
# ['человек', 'умный', 'кто', 'дорого', 'свой', 'здоровье', 'ехать', 'предел', 'край', 'делать', 'операция']
# ['глупость', 'говорить', 'у', 'один', 'знакомый', 'родственник', 'делать', 'операция', 'поллям', 'бесплатно', 'сустав', 'менять', 'уровень', 'врач', 'лечение', 'высокий']
# ['на', 'видео', 'министр', 'здравоохранение', 'попов', 'смешно', 'выглядеть', 'смонтировать', 'ролик']
# ['огласить', 'пожалуйста', 'весь', 'список', 'учреждение']
# ['просматривать', 'такой', 'новость', 'лично', 'возникать', 'вполне', 'резонный', 'вопрос', 'неужели', 'репортёр', 'власть', 'думать', 'житель', 'дебил', 'который', 'болеть', 'ходить', 'поликлиника', 'видеть', 'происходить', 'сам', 'дело', '🤔']

# %%
contain_emoji = contain_emoji.dropna()

# %%
contain_emoji
# Out:
#                                                 comment
# 0     [красавец, какой, удивительный, природа😊, стол...
# 1           [какой, это, человек, маленько, дотягивать]
# 4        [косоглазый, справа, конвергировать, страбизм]
# 7                                  [каков, красавец, 😍]
# 8     [зачем, ❓, собраться, убивать, это, тот, стрел...
# ...                                                 ...
# 1720  [человек, умный, кто, дорого, свой, здоровье, ...
# 1721  [глупость, говорить, у, один, знакомый, родств...
# 1722  [на, видео, министр, здравоохранение, попов, с...
# 1723   [огласить, пожалуйста, весь, список, учреждение]
# 1724  [просматривать, такой, новость, лично, возника...
#
# [1328 rows x 1 columns]
